# %%
import pandas as pd
df=pd.read_csv('/content/train (1).csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
#accessing the specific coluns
df['blue']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1995    1
# 1996    1
# 1997    0
# 1998    0
# 1999    1
# Name: blue, Length: 2000, dtype: int64

# %%
df.tail()  #accassing the data frames from last 5 rows
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
#changing the column names
df.rename(columns={'blue':'bluetooth','fc':'front camera','ram':'ram in gb','sc_h':'screen height','sc_w':'screen width'},inplace=True)
df.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front camera  four_g  \
# 0            842          0          2.2         0             1       0
# 1           1021          1          0.5         1             0       1
# 2            563          1          0.5         1             2       1
# 3            615          1          2.5         0             0       0
# 4           1821          1          1.2         0            13       1
#
#    int_memory  m_dep  mobile_wt  n_cores  ...  px_height  px_width  ram in gb  \
# 0           7    0.6        188        2  ...         20       756       2549
# 1          53    0.7        136        3  ...        905      1988       2631
# 2          41    0.9        145        5  ...       1263      1716       2603
# 3          10    0.8        131        6  ...       1216      1786       2769
# 4          44    0.6        141        2  ...       1208      1212       1411
#
# ...

# %%
#comparing the 4g with its price range
import seaborn as sns                                #x axis ---->   '0' no 4g                                                                     #"1" 4g is present
sns.barplot(df['four_g'],df['price_range'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#total size of 3g and 4g
df.groupby(['four_g','three_g']).size()
# Out:
# four_g  three_g
# 0       0           477
#         1           480
# 1       1          1043
# dtype: int64

# %%
df['three_g'].value_counts().plot(kind='bar')   #1=3g   #0=no 3g

# %%
from matplotlib import pyplot as plt
sns.barplot(df['battery_power'],df['mobile_wt'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-958188b8b3e2> in <module>()
#       2 sns.barplot(df['battery_power'],df['mobile_wt'])
#       3 plt.figure(figsize=[150,100])
# ----> 4 plt.rotate(xticks)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'rotate'

# %%
df=df.iloc[0:501,0:22]
df
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 496           1554     1          0.5         1  11       0           5
# 497           1337     0          0.5         0  13       0          31
# 498           1926     1          1.7         1   1       1          33
# 499            869     0          1.3         1   3       0          34
# 500           1278     1          0.5         1   1       0          54
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#total front cam with variable pixels phone
df["fc"].value_counts().plot(kind='bar')

# %%
from matplotlib import pyplot as plt
sns.barplot(df['battery_power'],df['mobile_wt'])
plt.figure(figsize=[20,15])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(df['dual_sim'],df['talk_time'])  #dual sim and talktime
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#changing columns to index      #battery power has been set as index
import pandas as pd
df1=pd.read_csv('/content/train (1).csv',index_col='battery_power')
df1
# Out:
#                blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# battery_power
# 842               0          2.2         0   1       0           7    0.6
# 1021              1          0.5         1   0       1          53    0.7
# 563               1          0.5         1   2       1          41    0.9
# 615               1          2.5         0   0       0          10    0.8
# 1821              1          1.2         0  13       1          44    0.6
# ...             ...          ...       ...  ..     ...         ...    ...
# 794               1          0.5         1   0       1           2    0.8
# 1965              1          2.6         1   0       0          39    0.2
# 1911              0          0.9         1   1       1          36    0.7
# 1512              0          0.9         0   4       1          46    0.1
# 510               1          2.0         1   5       1          45    0.9
#
# ...

# %%
#total number of various cored devices
df['n_cores'].value_counts().plot(kind='bar')

# %%
#comparing wifi and price range
sns.barplot(df['wifi'],df['price_range'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#chcecking which one has the highest battery power capacity
sns.distplot(df['battery_power'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#comparing touch screen and their price
sns.barplot(df['touch_screen'],df['price_range'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
